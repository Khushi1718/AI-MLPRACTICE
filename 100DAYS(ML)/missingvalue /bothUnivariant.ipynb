# %%
##random sample imputer
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/Users/khushi/AI-ML/100DAYS(ML)/train.csv',usecols=['Age','Fare','Survived'])

df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().mean() * 100
# Out:
# Survived     0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

X_train
# Out:
#       Age      Fare
# 30   40.0   27.7208
# 10    4.0   16.7000
# 873  47.0    9.0000
# 182   9.0   31.3875
# 876  20.0    9.8458
# ..    ...       ...
# 534  30.0    8.6625
# 584   NaN    8.7125
# 493  71.0   49.5042
# 527   NaN  221.7792
# 168   NaN   25.9250
#
# [712 rows x 2 columns]

# %%
X_train['Age_imputed'] = X_train['Age']
X_test['Age_imputed'] = X_test['Age']

# %%
X_test.tail()
# Out:
#       Age     Fare  Age_imputed
# 89   24.0   8.0500         24.0
# 80   22.0   9.0000         22.0
# 846   NaN  69.5500          NaN
# 870  26.0   7.8958         26.0
# 251  29.0  10.4625         29.0

# %%
##"Age_imputed mein jahan-jahan NaN hai, wahan original Age ke non-missing values
#mein se randomly utni values daal do jitni Age mein missing hain."

X_train.loc[X_train['Age_imputed'].isnull(), 'Age_imputed'] = (
    X_train['Age']
    .dropna()
    .sample(X_train['Age'].isnull().sum())
    .values
)
X_test.loc[X_test['Age_imputed'].isnull(), 'Age_imputed'] = (
    X_train['Age']
    .dropna()
    .sample(X_test['Age'].isnull().sum())
    .values
)

# %%
X_train
# Out:
#       Age      Fare  Age_imputed
# 30   40.0   27.7208         40.0
# 10    4.0   16.7000          4.0
# 873  47.0    9.0000         47.0
# 182   9.0   31.3875          9.0
# 876  20.0    9.8458         20.0
# ..    ...       ...          ...
# 534  30.0    8.6625         30.0
# 584   NaN    8.7125         40.0
# 493  71.0   49.5042         71.0
# 527   NaN  221.7792         47.0
# 168   NaN   25.9250         18.0
#
# [712 rows x 3 columns]

# %%
#distribution is same
sns.distplot(X_train['Age'],label='Original',hist=False)
sns.distplot(X_train['Age_imputed'],label = 'Imputed',hist=False)

plt.legend()
plt.show()
# Out:
# /var/folders/g7/2nb32w4138xgc8snhbpg3crw0000gn/T/ipykernel_53378/2500642265.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Age'],label='Original',hist=False)
# /var/folders/g7/2nb32w4138xgc8snhbpg3crw0000gn/T/ipykernel_53378/2500642265.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Age_imputed'],label = 'Imputed',hist=False)

# %%
## slight change in variance
print('Original variable variance: ', X_train['Age'].var())
print('Variance after random imputation: ', X_train['Age_imputed'].var())
# Out:
# Original variable variance:  204.34951339046142
# Variance after random imputation:  205.3487334020765

# %%
## covariance is changed
X_train[['Fare', 'Age', 'Age_imputed']].cov()
# Out:
#                     Fare         Age  Age_imputed
# Fare         2368.246832   71.512440    56.021186
# Age            71.512440  204.349513   204.349513
# Age_imputed    56.021186  204.349513   205.348733

# %%
##no oultliers
X_train[['Age', 'Age_imputed']].boxplot()
# Out:
# <Axes: >

# %%
sampled_value = X_train['Age'].dropna().sample(1, random_state=int(observation['Fare']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sampled_value = X_train['Age'].dropna().sample(1, random_state=int(observation['Fare']))
#
# NameError: name 'observation' is not defined

# %%
##missing -indicator 
df = pd.read_csv('/Users/khushi/AI-ML/100DAYS(ML)/train.csv',usecols=['Age','Fare','Survived'])

df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
X_train.head()
# Out:
#       Age     Fare
# 30   40.0  27.7208
# 10    4.0  16.7000
# 873  47.0   9.0000
# 182   9.0  31.3875
# 876  20.0   9.8458

# %%
si = SimpleImputer()
X_train_trf = si.fit_transform(X_train)
X_test_trf = si.transform(X_test)
X_train_trf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 si = SimpleImputer()
#       2 X_train_trf = si.fit_transform(X_train)
#       3 X_test_trf = si.transform(X_test)
#       4 X_train_trf
#
# NameError: name 'SimpleImputer' is not defined

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(X_train_trf,y_train)

y_pred = clf.predict(X_test_trf)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       1 from sklearn.linear_model import LogisticRegression
#       2
#       3 clf = LogisticRegression()
#       4
# ----> 5 clf.fit(X_train_trf,y_train)
#       6
#       7 y_pred = clf.predict(X_test_trf)
#       8
#
# NameError: name 'X_train_trf' is not defined

# %%
from sklearn.impute import MissingIndicator, SimpleImputer
X = df.drop(columns=['Survived']) 
y = df['Survived']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)


mi = MissingIndicator()

mi.fit(X_train)

X_train_missing = mi.transform(X_train)
X_test_missing = mi.transform(X_test)


X_train_missing = pd.DataFrame(
    X_train_missing,
    columns=['Age_NA'],
    index=X_train.index
)

X_test_missing = pd.DataFrame(
    X_test_missing,
    columns=['Age_NA'],
    index=X_test.index
)

X_train = pd.concat([X_train, X_train_missing], axis=1)
X_test = pd.concat([X_test, X_test_missing], axis=1)


si = SimpleImputer(strategy='mean')

X_train_trf2 = si.fit_transform(X_train)
X_test_trf2 = si.transform(X_test)

# %%
mi.features_
# Out:
# array([0])

# %%
## acccuracy inc
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

clf = LogisticRegression()

clf.fit(X_train_trf2, y_train)

y_pred = clf.predict(X_test_trf2)

accuracy_score(y_test, y_pred)
# Out:
# 0.6312849162011173

# %%
## add_indicator parameter is same as missing imputer is alag s nhi bna an
si = SimpleImputer(add_indicator=True)
X_train = si.fit_transform(X_train)
X_test = si.transform(X_test)
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(X_train_trf2,y_train)

y_pred = clf.predict(X_test_trf2)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6312849162011173

# %%
#automatic selcet imputer parameter
df = pd.read_csv('/Users/khushi/AI-ML/100DAYS(ML)/train.csv',usecols=['Age','Fare','Survived'])

df.head()

df.drop(columns=['PassengerId','Name','Ticket','Cabin'],inplace=True)
X = df.drop(columns=['Survived']) 
y = df['Survived']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 6
#       2 df = pd.read_csv('/Users/khushi/AI-ML/100DAYS(ML)/train.csv',usecols=['Age','Fare','Survived'])
#       3
#       4 df.head()
#       5
# ----> 6 df.drop(columns=['PassengerId','Name','Ticket','Cabin'],inplace=True)
#       7 X = df.drop(columns=['Survived'])
#       8 y = df['Survived']
#       9 X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
#
# File ~/Library/Python/3.14/lib/python/site-packages/pandas/core/frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File ~/Library/Python/3.14/lib/python/site-packages/pandas/core/generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4628         obj = self
#    4629
#    4630         for axis, labels in axes.items():
#    4631             if labels is not None:
# -> 4632                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4633
#    4634         if inplace:
#    4635             self._update_inplace(obj)
#
# File ~/Library/Python/3.14/lib/python/site-packages/pandas/core/generic.py:4674, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4670                 if not isinstance(axis, MultiIndex):
#    4671                     raise AssertionError("axis must be a MultiIndex")
#    4672                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4673             else:
# -> 4674                 new_axis = axis.drop(labels, errors=errors)
#    4675             indexer = axis.get_indexer(new_axis)
#    4676
#    4677         # Case for non-unique axis
#
# File ~/Library/Python/3.14/lib/python/site-packages/pandas/core/indexes/base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['PassengerId', 'Name', 'Ticket', 'Cabin'] not found in axis"

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression

numerical_features = ['Age', 'Fare']
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_features = ['Embarked', 'Sex']
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ohe',OneHotEncoder(handle_unknown='ignore'))
])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

# %%
clf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression())
])

# %%
from sklearn import set_config

set_config(display='diagram')
clf
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Fare']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Embarked', 'Sex'])])),
#                 ('classifier', LogisticRegression())])

# %%
param_grid = {
    'preprocessor__num__imputer__strategy': ['mean', 'median'],
    'preprocessor__cat__imputer__strategy': ['most_frequent', 'constant'],
    'classifier__C': [0.1, 1.0, 10, 100]
}

grid_search = GridSearchCV(clf, param_grid, cv=10)

# %%
grid_search.fit(X_train, y_train)

print(f"Best params:")
print(grid_search.best_params_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 grid_search.fit(X_train, y_train)
#       2
#       3 print(f"Best params:")
#       4 print(grid_search.best_params_)
#
# File ~/Library/Python/3.14/lib/python/site-packages/sklearn/base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~/Library/Python/3.14/lib/python/site-packages/sklearn/model_selection/_search.py:1131, in BaseSearchCV.fit(self, X, y, **params)
#    1128     return results
#    1130 if "callback_ctx" in signature(self._run_search).parameters:
# -> 1131     self._run_search(evaluate_candidates, callback_ctx=root_callback_ctx)
#    1132 else:
#    1133     # custom search classes
#    1134     self._run_search(evaluate_candidates)
#
# File ~/Library/Python/3.14/lib/python/site-packages/sklearn/model_selection/_search.py:1718, in GridSearchCV._run_search(self, evaluate_candidates, callback_ctx)
#    1710 candidate_params = ParameterGrid(self.param_grid)
#    1712 search_ctx = callback_ctx.subcontext(
#    1713     task_name="search",
#    1714     max_subtasks=len(candidate_params) * self.n_splits_,
#    1715     sequential_subtasks=False,
#    1716 ).call_on_fit_task_begin(estimator=self)
# -> 1718 evaluate_candidates(ParameterGrid(self.param_grid), callback_ctx=search_ctx)
#    1720 search_ctx.call_on_fit_task_end(estimator=self)
#
# File ~/Library/Python/3.14/lib/python/site-packages/sklearn/model_selection/_search.py:1107, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results, callback_ctx)
#    1100 if len(out) < 1:
#    1101     raise ValueError(
#    1102         "No fits were performed. "
#    1103         "Was the CV iterator empty? "
#    1104         "Were there no candidates?"
#    1105     )
# -> 1107 _warn_or_raise_about_fit_failures(out, self.error_score)
#    1109 # For callable self.scoring, the return type is only know after
#    1110 # calling. If the return type is a dictionary, the error scores
#    1111 # can now be inserted with the correct key. The type checking
#    1112 # of out will be done in `_insert_error_scores`.
#    1113 if callable(self.scoring):
#
# File ~/Library/Python/3.14/lib/python/site-packages/sklearn/model_selection/_validation.py:478, in _warn_or_raise_about_fit_failures(results, error_score)
#     471 if num_failed_fits == num_fits:
#     472     all_fits_failed_message = (
#     473         f"\nAll the {num_fits} fits failed.\n"
#     474         "It is very likely that your model is misconfigured.\n"
#     475         "You can try to debug the error by setting error_score='raise'.\n\n"
#     476         f"Below are more details about the failures:\n{fit_errors_summary}"
#     477     )
# --> 478     raise ValueError(all_fits_failed_message)
#     480 else:
#     481     some_fits_failed_message = (
#     482         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     483         "The score on these train-test partitions for these parameters"
#    (...)    487         f"Below are more details about the failures:\n{fit_errors_summary}"
#     488     )
#
# ValueError:
# All the 160 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 160 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/khushi/Library/Python/3.14/lib/python/site-packages/sklearn/model_selection/_validation.py", line 851, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/khushi/Library/Python/3.14/lib/python/site-packages/sklearn/base.py", line 1403, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/khushi/Library/Python/3.14/lib/python/site-packages/sklearn/pipeline.py", line 636, in fit
#     Xt = self._fit(
#         X, y, routed_params, raw_params=params, callback_ctx=callback_ctx
#     )
#   File "/Users/khushi/Library/Python/3.14/lib/python/site-packages/sklearn/pipeline.py", line 565, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ~~~~~~~~~~~~~~~~~~~~~~~~^
#         cloned_transformer,
#         ^^^^^^^^^^^^^^^^^^^
#     ...<7 lines>...
#         callback_ctx=subcontext,
#         ^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/khushi/Library/Python/3.14/lib/python/site-packages/joblib/memory.py", line 326, in __call__
#     return self.func(*args, **kwargs)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/khushi/Library/Python/3.14/lib/python/site-packages/sklearn/pipeline.py", line 1593, in _fit_transform_one_with_callbacks
#     Xt, transformer = _fit_transform_one(
#                       ~~~~~~~~~~~~~~~~~~^
#         transformer, X, y, weight, message_clsname, message, params
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/khushi/Library/Python/3.14/lib/python/site-packages/sklearn/pipeline.py", line 1566, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#   File "/Users/khushi/Library/Python/3.14/lib/python/site-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/Users/khushi/Library/Python/3.14/lib/python/site-packages/sklearn/base.py", line 1403, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/khushi/Library/Python/3.14/lib/python/site-packages/sklearn/compose/_column_transformer.py", line 971, in fit_transform
#     self._validate_column_callables(X)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "/Users/khushi/Library/Python/3.14/lib/python/site-packages/sklearn/compose/_column_transformer.py", line 526, in _validate_column_callables
#     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#                                          ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/Users/khushi/Library/Python/3.14/lib/python/site-packages/sklearn/utils/_indexing.py", line 391, in _get_column_indices
#     raise ValueError(
#         "Specifying the columns using strings is only supported for dataframes."
#     )
# ValueError: Specifying the columns using strings is only supported for dataframes.

# %%
print(f"Internal CV score: {grid_search.best_score_:.3f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print(f"Internal CV score: {grid_search.best_score_:.3f}")
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_score_'

# %%
import pandas as pd

cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results = cv_results.sort_values("mean_test_score", ascending=False)
cv_results[['param_classifier__C','param_preprocessor__cat__imputer__strategy','param_preprocessor__num__imputer__strategy','mean_test_score']]
