# %%
import pickle
import numpy as np 
pipe= pickle.load(open('pipe.pkl','rb'))

# %%
## user input
input_user= np.array([2,'male',31.0,0,0,10.5,'S'].dtype=object).reshape(1,7)

# %%
pipe.predict(input_user)
