# %%
import pandas as pd 
data = pd.read_csv('placement.csv')

# %% [markdown]
# 1.How big the data?

# %%
data.shape
# Out:
# (60, 8)

# %% [markdown]
# 2.How does daat look like

# %%
data.sample(5) # 5 random rows
# Out:
#    student_id  cgpa  attendance     iq  internships branch   placement  \
# 24     STU025   7.5        79.0  106.0          1.0    CSE      Placed
# 12     STU013   5.8        59.0   84.0          0.0     ME  Not Placed
# 45     STU046   8.8        91.0  131.0          3.0    ECE      Placed
# 30     STU031   8.3        88.0  122.0          2.0    CSE      Placed
# 55     STU056   6.9        72.0   97.0          0.0     CE  Not Placed
#
#     package_lpa
# 24          5.5
# 12          0.0
# 45          9.0
# 30          7.9
# 55          NaN

# %% [markdown]
# 3.what type of cols

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   60 non-null     str
#  1   cgpa         58 non-null     float64
#  2   attendance   58 non-null     float64
#  3   iq           59 non-null     float64
#  4   internships  59 non-null     float64
#  5   branch       60 non-null     str
#  6   placement    60 non-null     str
#  7   package_lpa  59 non-null     float64
# dtypes: float64(5), str(3)
# memory usage: 3.9 KB

# %%
4.are there any missing values

# %%
data.isnull().sum()
# Out:
# student_id     0
# cgpa           2
# attendance     2
# iq             1
# internships    1
# branch         0
# placement      0
# package_lpa    1
# dtype: int64

# %%
5.how does the data look mathematically

# %%
data.describe()
# Out:
#             cgpa  attendance          iq  internships  package_lpa
# count  58.000000   58.000000   59.000000    59.000000    59.000000
# mean    7.510345   79.500000  108.728814     1.237288     9.164407
# std     1.241630   12.247807   19.100307     1.222476    32.157134
# min     2.100000   35.000000   40.000000     0.000000     0.000000
# 25%     6.800000   71.250000   96.500000     0.000000     0.000000
# 50%     7.600000   81.500000  108.000000     1.000000     5.900000
# 75%     8.375000   88.750000  121.500000     2.000000     7.850000
# max    10.000000   99.000000  150.000000     5.000000   250.000000

# %% [markdown]
# 6. are the duplicte values

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#correlation of cols
data.corr()
data.correlation.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 #correlation of cols
# ----> 2 data.corr()
#
# File ~/Library/Python/3.14/lib/python/site-packages/pandas/core/frame.py:13135, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13131         """  # noqa: E501
#   13132         data = self._get_numeric_data() if numeric_only else self
#   13133         cols = data.columns
#   13134         idx = cols.copy()
# > 13135         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13136
#   13137         if method == "pearson":
#   13138             correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Library/Python/3.14/lib/python/site-packages/pandas/core/frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2077                [2, 4.5, Timestamp('2000-01-02 00:00:00')]], dtype=object)
# ...
