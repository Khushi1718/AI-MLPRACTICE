# %%
import requests

url = "https://api.example.com/students"

response = requests.get(url)

print(response.status_code)
print(response.json())
data = response.json()

df = pd.DataFrame(data)

print(df.head)

# with headers
# headers = {
#     "User-Agent": "Mozilla/5.0"
# }

# response = requests.get(url, headers=headers)

# %% [markdown]
# Python
#   ↓ request
# API / Server
#   ↓ response
# JSON
#   ↓
# Pandas DataFrame

# %%
import requests
import pandas as pd

url = "https://api.themoviedb.org/3/movie/11"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiNTQwODFmMWQ2ZjAzNWIxN2U4ODVkODgxNjE3MDhiOCIsIm5iZiI6MTc4OTMyMjU3OC40OTUwMDAxLCJzdWIiOiI2YWE2ZTU1MjI3MDIyMmIyNGZhOTgzNDAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.5tRiN67aemExxZFCyoHIoSarOP5D_ByPe9ErxSsijsE"
}

response = requests.get(url, headers=headers, timeout=20)

print(response.status_code)

data = response.json()

df = pd.DataFrame([data])

df
# Out:
# 200
#    adult                     backdrop_path  \
# 0  False  /zqkmTXzjkAgXmEWLRsY4UpTWCeo.jpg
#
#                                belongs_to_collection    budget  \
# 0  {'id': 10, 'name': 'Star Wars Collection', 'po...  11000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                             homepage  id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  11  tt0076759
#
#   origin_country original_language  ...    revenue runtime  softcore  \
# 0           [US]                en  ...  775398007     121     False
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                         tagline      title  video  \
# 0  A long time ago in a galaxy far, far away...  Star Wars  False
#
#    vote_average  vote_count
# 0         8.207       22845
#
# ...
